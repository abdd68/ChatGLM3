# %% [markdown]
# # 单卡GPU 进行 ChatGLM3-6B模型 LORA 高效微调
# 本 Cookbook 将带领开发者使用 `AdvertiseGen` 对 ChatGLM3-6B 数据集进行 lora微调，使其具备专业的广告生成能力。
#
# ## 硬件需求
# 显存：24GB及以上（推荐使用30系或A10等sm80架构以上的NVIDIA显卡进行尝试）
# 内存：16GB
# RAM: 2.9 /16 GB
# GPU RAM: 15.5/16.0 GB

# %% [markdown]
# ## 0. 环境检查
# 首先，先检查代码的运行地址，确保运行地址处于 `finetune_demo` 中。
# 并且，确保已经安装了 `requirements.txt`中的依赖。
#
# > 本 demo 中，不需要使用 deepspeed, mpi4py 两个依赖，如果您安装这两个依赖遇到问题，可以不安装这两个依赖。

# %%
# !pwd
# Out:
# /codespace/ChatGLM3/finetune_demo

# %% [markdown]
# ## 1. 准备数据集
# 我们使用 AdvertiseGen 数据集来进行微调。从 [Google Drive](https://drive.google.com/file/d/13_vf0xRTQsyneRKdD1bZIr93vBGOczrk/view?usp=sharing) 或者 [Tsinghua Cloud](https://cloud.tsinghua.edu.cn/f/b3f119a008264b1cabd1/?dl=1) 下载处理好的 AdvertiseGen 数据集，将解压后的 AdvertiseGen 目录放到本目录的 `/data/` 下, 例如。
# > /media/zr/Data/Code/ChatGLM3/finetune_demo/data/AdvertiseGen

# %%
import json
from typing import Union
from pathlib import Path


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def _mkdir(dir_name: Union[str, Path]):
    dir_name = _resolve_path(dir_name)
    if not dir_name.is_dir():
        dir_name.mkdir(parents=True, exist_ok=False)


def convert_adgen(data_dir: Union[str, Path], save_dir: Union[str, Path]):
    def _convert(in_file: Path, out_file: Path):
        _mkdir(out_file.parent)
        with open(in_file, encoding='utf-8') as fin:
            with open(out_file, 'wt', encoding='utf-8') as fout:
                for line in fin:
                    dct = json.loads(line)
                    sample = {'conversations': [{'role': 'user', 'content': dct['content']},
                                                {'role': 'assistant', 'content': dct['summary']}]}
                    fout.write(json.dumps(sample, ensure_ascii=False) + '\n')

    data_dir = _resolve_path(data_dir)
    save_dir = _resolve_path(save_dir)

    train_file = data_dir / 'train.json'
    if train_file.is_file():
        out_file = save_dir / train_file.relative_to(data_dir)
        _convert(train_file, out_file)

    dev_file = data_dir / 'dev.json'
    if dev_file.is_file():
        out_file = save_dir / dev_file.relative_to(data_dir)
        _convert(dev_file, out_file)


convert_adgen('data/AdvertiseGen', 'data/AdvertiseGen_fix')

# %% [markdown]
# ## 2. 使用命令行开始微调,我们使用 lora 进行微调
# 接着，我们仅需要将配置好的参数以命令行的形式传参给程序，就可以使用命令行进行高效微调。

# %%
# !CUDA_VISIBLE_DEVICES=0 NCCL_P2P_DISABLE="1" NCCL_IB_DISABLE="1" python finetune_hf.py  data/AdvertiseGen_fix  THUDM/chatglm3-6b  configs/lora.yaml
# Out:
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:02<00:00,  2.51it/s]
# trainable params: 1,949,696 || all params: 6,245,533,696 || trainable%: 0.031217444255383614
# --> Model
#
# --> model has 1.949696M params
#
# Setting num_proc from 16 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 114599 examples [00:00, 1179567.26 examples/s]
# Setting num_proc from 16 back to 1 for the validation split to disable multiprocessing as it only contains one shard.
# Generating validation split: 1070 examples [00:00, 325540.79 examples/s]
# Setting num_proc from 16 back to 1 for the test split to disable multiprocessing as it only contains one shard.
# Generating test split: 1070 examples [00:00, 297369.82 examples/s]
# Map (num_proc=16): 100%|███████| 114599/114599 [00:14<00:00, 8012.78 examples/s]
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 114599
# })
# Map (num_proc=16): 100%|████████████| 1070/1070 [00:01<00:00, 725.98 examples/s]
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# Map (num_proc=16): 100%|████████████| 1070/1070 [00:01<00:00, 730.64 examples/s]
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# --> Sanity check
#            '[gMASK]': 64790 -> -100
#                'sop': 64792 -> -100
#           '<|user|>': 64795 -> -100
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裤': 56532 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '性感': 40589 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '裤': 56532 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '阔': 56529 -> -100
#                  '腿': 56158 -> -100
#                  '裤': 56532 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '阔': 56529 -> 56529
#                  '腿': 56158 -> 56158
#                  '裤': 56532 -> 56532
#                  '这': 54551 -> 54551
#                 '两年': 33808 -> 33808
#                 '真的': 32041 -> 32041
#                  '吸': 55360 -> 55360
#                  '粉': 55486 -> 55486
#                 '不少': 32138 -> 32138
#                  '，': 31123 -> 31123
#                 '明星': 32943 -> 32943
#                 '时尚': 33481 -> 33481
#                  '达': 54880 -> 54880
#                 '人的': 31664 -> 31664
#                 '心头': 46565 -> 46565
#                  '爱': 54799 -> 54799
#                  '。': 31155 -> 31155
#                 '毕竟': 33051 -> 33051
#                  '好': 54591 -> 54591
#                  '穿': 55432 -> 55432
#                 '时尚': 33481 -> 33481
#                  '，': 31123 -> 31123
#                  '谁': 55622 -> 55622
#                 '都能': 32904 -> 32904
#                  '穿': 55432 -> 55432
#                  '出': 54557 -> 54557
#                  '腿': 56158 -> 56158
#                  '长': 54625 -> 54625
#                  '2': 30943 -> 30943
#                  '米': 55055 -> 55055
#                '的效果': 35590 -> 35590
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '裤': 56532 -> 56532
#                  '腿': 56158 -> 56158
#                  '，': 31123 -> 31123
#                '当然是': 48466 -> 48466
#                  '遮': 57148 -> 57148
#                  '肉': 55343 -> 55343
#                  '小': 54603 -> 54603
#                 '能手': 49355 -> 49355
#                  '啊': 55674 -> 55674
#                  '。': 31155 -> 31155
#                 '上身': 51605 -> 51605
#                  '随': 55119 -> 55119
#                  '性': 54642 -> 54642
#                 '自然': 31799 -> 31799
#                  '不': 54535 -> 54535
#                  '拘': 57036 -> 57036
#                  '束': 55625 -> 55625
#                  '，': 31123 -> 31123
#                 '面料': 46839 -> 46839
#                  '亲': 55113 -> 55113
#                  '肤': 56089 -> 56089
#                 '舒适': 33894 -> 33894
#                  '贴': 55778 -> 55778
#                 '身体': 31902 -> 31902
#                  '验': 55017 -> 55017
#                  '感': 54706 -> 54706
#                  '棒': 56382 -> 56382
#                  '棒': 56382 -> 56382
#                  '哒': 59230 -> 59230
#                  '。': 31155 -> 31155
#                  '系': 54712 -> 54712
#                  '带': 54882 -> 54882
#                 '部分': 31726 -> 31726
#                 '增加': 31917 -> 31917
#                 '设计': 31735 -> 31735
#                 '看点': 45032 -> 45032
#                  '，': 31123 -> 31123
#                  '还': 54656 -> 54656
#                  '让': 54772 -> 54772
#                 '单品': 46539 -> 46539
#                '的设计': 34481 -> 34481
#                  '感': 54706 -> 54706
#                 '更强': 43084 -> 43084
#                  '。': 31155 -> 31155
#                 '腿部': 46799 -> 46799
#                 '线条': 37216 -> 37216
#                  '若': 55351 -> 55351
#                  '隐': 55733 -> 55733
#                  '若': 55351 -> 55351
#                  '现': 54600 -> 54600
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                 '性感': 40589 -> 40589
#                  '撩': 58521 -> 58521
#                  '人': 54533 -> 54533
#                  '。': 31155 -> 31155
#                 '颜色': 33692 -> 33692
#                  '敲': 57004 -> 57004
#                 '温柔': 34678 -> 34678
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                  '与': 54619 -> 54619
#                 '裤子': 44722 -> 44722
#                 '本身': 32754 -> 32754
#                  '所': 54626 -> 54626
#                 '呈现': 33169 -> 33169
#                '的风格': 48084 -> 48084
#                 '有点': 33149 -> 33149
#                  '反': 54955 -> 54955
#                  '差': 55342 -> 55342
#                  '萌': 56842 -> 56842
#                  '。': 31155 -> 31155
#                   '': 2 -> 2
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 114,599
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3,000
#   Number of trainable parameters = 1,949,696
# {'loss': 4.8277, 'grad_norm': 2.252188205718994, 'learning_rate': 4.9833333333333336e-05, 'epoch': 0.0}
# {'loss': 4.5918, 'grad_norm': 3.1846508979797363, 'learning_rate': 4.966666666666667e-05, 'epoch': 0.0}
# {'loss': 4.4711, 'grad_norm': 3.0137972831726074, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.0}
# {'loss': 4.1107, 'grad_norm': 3.351745843887329, 'learning_rate': 4.933333333333334e-05, 'epoch': 0.0}
# {'loss': 4.1072, 'grad_norm': 2.7138442993164062, 'learning_rate': 4.9166666666666665e-05, 'epoch': 0.0}
# {'loss': 3.8641, 'grad_norm': 2.9382221698760986, 'learning_rate': 4.9e-05, 'epoch': 0.0}
# {'loss': 3.8379, 'grad_norm': 2.893251657485962, 'learning_rate': 4.883333333333334e-05, 'epoch': 0.0}
# {'loss': 3.7461, 'grad_norm': 2.958009958267212, 'learning_rate': 4.866666666666667e-05, 'epoch': 0.0}
# {'loss': 3.6332, 'grad_norm': 3.206664800643921, 'learning_rate': 4.85e-05, 'epoch': 0.0}
# {'loss': 3.7189, 'grad_norm': 3.401546001434326, 'learning_rate': 4.8333333333333334e-05, 'epoch': 0.0}
# {'loss': 3.6725, 'grad_norm': 3.601102828979492, 'learning_rate': 4.8166666666666674e-05, 'epoch': 0.0}
# {'loss': 3.8471, 'grad_norm': 3.8779044151306152, 'learning_rate': 4.8e-05, 'epoch': 0.0}
# {'loss': 3.6139, 'grad_norm': 3.481410264968872, 'learning_rate': 4.7833333333333335e-05, 'epoch': 0.0}
# {'loss': 3.7324, 'grad_norm': 4.398871898651123, 'learning_rate': 4.766666666666667e-05, 'epoch': 0.0}
# {'loss': 3.6822, 'grad_norm': 3.6420023441314697, 'learning_rate': 4.75e-05, 'epoch': 0.01}
# {'loss': 3.7436, 'grad_norm': 3.8855624198913574, 'learning_rate': 4.7333333333333336e-05, 'epoch': 0.01}
# {'loss': 3.5752, 'grad_norm': 4.087100505828857, 'learning_rate': 4.716666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5756, 'grad_norm': 4.334571838378906, 'learning_rate': 4.7e-05, 'epoch': 0.01}
# {'loss': 3.55, 'grad_norm': 4.708095073699951, 'learning_rate': 4.683333333333334e-05, 'epoch': 0.01}
# {'loss': 3.5779, 'grad_norm': 4.503207683563232, 'learning_rate': 4.666666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5521, 'grad_norm': 4.999374866485596, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.01}
# {'loss': 3.6479, 'grad_norm': 4.029660224914551, 'learning_rate': 4.633333333333333e-05, 'epoch': 0.01}
# {'loss': 3.6088, 'grad_norm': 4.733814716339111, 'learning_rate': 4.6166666666666666e-05, 'epoch': 0.01}
# {'loss': 3.5102, 'grad_norm': 4.489063262939453, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.01}
# {'loss': 3.4758, 'grad_norm': 5.3609795570373535, 'learning_rate': 4.5833333333333334e-05, 'epoch': 0.01}
# {'loss': 3.6033, 'grad_norm': 5.259022235870361, 'learning_rate': 4.566666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5506, 'grad_norm': 5.356853485107422, 'learning_rate': 4.55e-05, 'epoch': 0.01}
# {'loss': 3.6125, 'grad_norm': 4.549736499786377, 'learning_rate': 4.5333333333333335e-05, 'epoch': 0.01}
# {'loss': 3.6301, 'grad_norm': 4.742580413818359, 'learning_rate': 4.516666666666667e-05, 'epoch': 0.01}
# {'loss': 3.5385, 'grad_norm': 5.858244895935059, 'learning_rate': 4.5e-05, 'epoch': 0.01}
# {'loss': 3.4666, 'grad_norm': 5.265252590179443, 'learning_rate': 4.483333333333333e-05, 'epoch': 0.01}
# {'loss': 3.6076, 'grad_norm': 5.75539493560791, 'learning_rate': 4.466666666666667e-05, 'epoch': 0.01}
# {'loss': 3.4174, 'grad_norm': 5.196459770202637, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.01}
# {'loss': 3.4928, 'grad_norm': 5.373425483703613, 'learning_rate': 4.433333333333334e-05, 'epoch': 0.01}
# {'loss': 3.5199, 'grad_norm': 5.470030307769775, 'learning_rate': 4.4166666666666665e-05, 'epoch': 0.01}
# {'loss': 3.5732, 'grad_norm': 5.1815571784973145, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.01}
# {'loss': 3.3576, 'grad_norm': 4.830959320068359, 'learning_rate': 4.383333333333334e-05, 'epoch': 0.01}
# {'loss': 3.5312, 'grad_norm': 5.157874584197998, 'learning_rate': 4.3666666666666666e-05, 'epoch': 0.01}
# {'loss': 3.5227, 'grad_norm': 5.280559062957764, 'learning_rate': 4.35e-05, 'epoch': 0.01}
# {'loss': 3.4719, 'grad_norm': 5.615904808044434, 'learning_rate': 4.3333333333333334e-05, 'epoch': 0.01}
# {'loss': 3.6898, 'grad_norm': 5.464376926422119, 'learning_rate': 4.316666666666667e-05, 'epoch': 0.01}
# {'loss': 3.4977, 'grad_norm': 5.03904914855957, 'learning_rate': 4.3e-05, 'epoch': 0.01}
# {'loss': 3.6217, 'grad_norm': 5.6338911056518555, 'learning_rate': 4.2833333333333335e-05, 'epoch': 0.02}
# {'loss': 3.4158, 'grad_norm': 6.518835067749023, 'learning_rate': 4.266666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4152, 'grad_norm': 5.966553688049316, 'learning_rate': 4.25e-05, 'epoch': 0.02}
# {'loss': 3.4266, 'grad_norm': 5.620908737182617, 'learning_rate': 4.233333333333334e-05, 'epoch': 0.02}
# {'loss': 3.5307, 'grad_norm': 5.785429000854492, 'learning_rate': 4.216666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4465, 'grad_norm': 7.0392165184021, 'learning_rate': 4.2e-05, 'epoch': 0.02}
# {'loss': 3.4594, 'grad_norm': 5.822317123413086, 'learning_rate': 4.183333333333334e-05, 'epoch': 0.02}
# {'loss': 3.5631, 'grad_norm': 5.93325662612915, 'learning_rate': 4.166666666666667e-05, 'epoch': 0.02}
#  17%|██████▋                                 | 500/3000 [06:40<28:37,  1.46it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:24<00:24, 12.20s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:29<00:09,  9.44s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:51<00:00, 14.13s/it]Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.500 seconds.
# Prefix dict has been built successfully.
#
# {'eval_rouge-1': 30.955248, 'eval_rouge-2': 6.831338000000001, 'eval_rouge-l': 24.148206000000002, 'eval_bleu-4': 0.03265931605475633, 'eval_runtime': 57.2831, 'eval_samples_per_second': 0.873, 'eval_steps_per_second': 0.07, 'epoch': 0.02}
#  17%|██████▋                                 | 500/3000 [07:38<28:37,  1.46it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:52<00:00, 14.13s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-500
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3213, 'grad_norm': 5.732199192047119, 'learning_rate': 4.15e-05, 'epoch': 0.02}
# {'loss': 3.5459, 'grad_norm': 6.593526363372803, 'learning_rate': 4.133333333333333e-05, 'epoch': 0.02}
# {'loss': 3.5846, 'grad_norm': 6.039732456207275, 'learning_rate': 4.116666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4848, 'grad_norm': 5.363999366760254, 'learning_rate': 4.1e-05, 'epoch': 0.02}
# {'loss': 3.5232, 'grad_norm': 5.351800441741943, 'learning_rate': 4.0833333333333334e-05, 'epoch': 0.02}
# {'loss': 3.6434, 'grad_norm': 5.75950288772583, 'learning_rate': 4.066666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4918, 'grad_norm': 5.800402641296387, 'learning_rate': 4.05e-05, 'epoch': 0.02}
# {'loss': 3.3691, 'grad_norm': 5.54358434677124, 'learning_rate': 4.0333333333333336e-05, 'epoch': 0.02}
# {'loss': 3.4238, 'grad_norm': 6.2516374588012695, 'learning_rate': 4.016666666666667e-05, 'epoch': 0.02}
# {'loss': 3.49, 'grad_norm': 6.466867446899414, 'learning_rate': 4e-05, 'epoch': 0.02}
# {'loss': 3.4334, 'grad_norm': 6.245785236358643, 'learning_rate': 3.983333333333333e-05, 'epoch': 0.02}
# {'loss': 3.4574, 'grad_norm': 6.741954803466797, 'learning_rate': 3.966666666666667e-05, 'epoch': 0.02}
# {'loss': 3.4479, 'grad_norm': 5.929683685302734, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.02}
# {'loss': 3.4557, 'grad_norm': 6.105165004730225, 'learning_rate': 3.933333333333333e-05, 'epoch': 0.02}
# {'loss': 3.5309, 'grad_norm': 5.921173572540283, 'learning_rate': 3.9166666666666665e-05, 'epoch': 0.02}
# {'loss': 3.4818, 'grad_norm': 6.328170299530029, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.02}
# {'loss': 3.5404, 'grad_norm': 6.143426895141602, 'learning_rate': 3.883333333333333e-05, 'epoch': 0.02}
# {'loss': 3.3045, 'grad_norm': 6.891308307647705, 'learning_rate': 3.866666666666667e-05, 'epoch': 0.02}
# {'loss': 3.3959, 'grad_norm': 6.612732410430908, 'learning_rate': 3.85e-05, 'epoch': 0.02}
# {'loss': 3.3506, 'grad_norm': 6.2100300788879395, 'learning_rate': 3.8333333333333334e-05, 'epoch': 0.02}
# {'loss': 3.4984, 'grad_norm': 7.026381969451904, 'learning_rate': 3.816666666666667e-05, 'epoch': 0.02}
# {'loss': 3.5264, 'grad_norm': 6.803094387054443, 'learning_rate': 3.8e-05, 'epoch': 0.03}
# {'loss': 3.2492, 'grad_norm': 6.890865802764893, 'learning_rate': 3.7833333333333336e-05, 'epoch': 0.03}
# {'loss': 3.5703, 'grad_norm': 5.858427047729492, 'learning_rate': 3.766666666666667e-05, 'epoch': 0.03}
# {'loss': 3.3971, 'grad_norm': 6.4853315353393555, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.03}
# {'loss': 3.476, 'grad_norm': 6.137809753417969, 'learning_rate': 3.733333333333334e-05, 'epoch': 0.03}
# {'loss': 3.6201, 'grad_norm': 6.3585028648376465, 'learning_rate': 3.7166666666666664e-05, 'epoch': 0.03}
# {'loss': 3.4719, 'grad_norm': 6.287313461303711, 'learning_rate': 3.7e-05, 'epoch': 0.03}
# {'loss': 3.3258, 'grad_norm': 6.395381450653076, 'learning_rate': 3.683333333333334e-05, 'epoch': 0.03}
# {'loss': 3.5479, 'grad_norm': 6.816625118255615, 'learning_rate': 3.6666666666666666e-05, 'epoch': 0.03}
# {'loss': 3.2879, 'grad_norm': 6.566320419311523, 'learning_rate': 3.65e-05, 'epoch': 0.03}
# {'loss': 3.3584, 'grad_norm': 6.528183460235596, 'learning_rate': 3.633333333333333e-05, 'epoch': 0.03}
# {'loss': 3.4557, 'grad_norm': 7.112440586090088, 'learning_rate': 3.6166666666666674e-05, 'epoch': 0.03}
# {'loss': 3.4039, 'grad_norm': 6.311846733093262, 'learning_rate': 3.6e-05, 'epoch': 0.03}
# {'loss': 3.5078, 'grad_norm': 6.239538669586182, 'learning_rate': 3.5833333333333335e-05, 'epoch': 0.03}
# {'loss': 3.5352, 'grad_norm': 6.351250648498535, 'learning_rate': 3.566666666666667e-05, 'epoch': 0.03}
# {'loss': 3.2896, 'grad_norm': 7.163177490234375, 'learning_rate': 3.55e-05, 'epoch': 0.03}
# {'loss': 3.4949, 'grad_norm': 6.708476543426514, 'learning_rate': 3.5333333333333336e-05, 'epoch': 0.03}
# {'loss': 3.4506, 'grad_norm': 7.48862886428833, 'learning_rate': 3.516666666666667e-05, 'epoch': 0.03}
# {'loss': 3.2629, 'grad_norm': 7.890026092529297, 'learning_rate': 3.5e-05, 'epoch': 0.03}
# {'loss': 3.4576, 'grad_norm': 7.792075157165527, 'learning_rate': 3.483333333333334e-05, 'epoch': 0.03}
# {'loss': 3.4203, 'grad_norm': 6.971055507659912, 'learning_rate': 3.466666666666667e-05, 'epoch': 0.03}
# {'loss': 3.4627, 'grad_norm': 7.523808479309082, 'learning_rate': 3.45e-05, 'epoch': 0.03}
# {'loss': 3.5658, 'grad_norm': 7.3966217041015625, 'learning_rate': 3.433333333333333e-05, 'epoch': 0.03}
# {'loss': 3.3605, 'grad_norm': 6.449216842651367, 'learning_rate': 3.4166666666666666e-05, 'epoch': 0.03}
# {'loss': 3.4371, 'grad_norm': 7.842874050140381, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.03}
# {'loss': 3.534, 'grad_norm': 5.911130428314209, 'learning_rate': 3.3833333333333334e-05, 'epoch': 0.03}
# {'loss': 3.323, 'grad_norm': 6.894315242767334, 'learning_rate': 3.366666666666667e-05, 'epoch': 0.03}
# {'loss': 3.4584, 'grad_norm': 7.318764686584473, 'learning_rate': 3.35e-05, 'epoch': 0.03}
# {'loss': 3.3955, 'grad_norm': 7.7330451011657715, 'learning_rate': 3.3333333333333335e-05, 'epoch': 0.03}
#  33%|█████████████                          | 1000/3000 [13:18<25:08,  1.33it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:03<00:03,  1.96s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:07<00:02,  2.66s/it]
#
# {'eval_rouge-1': 32.376126000000006, 'eval_rouge-2': 6.738308000000001, 'eval_rouge-l': 25.820702, 'eval_bleu-4': 0.033858562945363435, 'eval_runtime': 14.2397, 'eval_samples_per_second': 3.511, 'eval_steps_per_second': 0.281, 'epoch': 0.03}
#  33%|█████████████                          | 1000/3000 [13:32<25:08,  1.33it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.42s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-1000
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.4463, 'grad_norm': 6.951918125152588, 'learning_rate': 3.316666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4598, 'grad_norm': 7.421215057373047, 'learning_rate': 3.3e-05, 'epoch': 0.04}
# {'loss': 3.649, 'grad_norm': 8.183662414550781, 'learning_rate': 3.283333333333333e-05, 'epoch': 0.04}
# {'loss': 3.4059, 'grad_norm': 6.568378448486328, 'learning_rate': 3.266666666666667e-05, 'epoch': 0.04}
# {'loss': 3.3873, 'grad_norm': 8.751686096191406, 'learning_rate': 3.2500000000000004e-05, 'epoch': 0.04}
# {'loss': 3.3588, 'grad_norm': 7.831490993499756, 'learning_rate': 3.233333333333333e-05, 'epoch': 0.04}
# {'loss': 3.3854, 'grad_norm': 7.154478073120117, 'learning_rate': 3.2166666666666665e-05, 'epoch': 0.04}
# {'loss': 3.4598, 'grad_norm': 7.257074356079102, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.04}
# {'loss': 3.526, 'grad_norm': 7.2312421798706055, 'learning_rate': 3.183333333333334e-05, 'epoch': 0.04}
# {'loss': 3.465, 'grad_norm': 6.525638580322266, 'learning_rate': 3.1666666666666666e-05, 'epoch': 0.04}
# {'loss': 3.3477, 'grad_norm': 6.949716567993164, 'learning_rate': 3.15e-05, 'epoch': 0.04}
# {'loss': 3.524, 'grad_norm': 8.071700096130371, 'learning_rate': 3.1333333333333334e-05, 'epoch': 0.04}
# {'loss': 3.4326, 'grad_norm': 7.45495080947876, 'learning_rate': 3.116666666666667e-05, 'epoch': 0.04}
# {'loss': 3.3576, 'grad_norm': 8.211015701293945, 'learning_rate': 3.1e-05, 'epoch': 0.04}
# {'loss': 3.3172, 'grad_norm': 7.582859992980957, 'learning_rate': 3.0833333333333335e-05, 'epoch': 0.04}
# {'loss': 3.3631, 'grad_norm': 7.029067516326904, 'learning_rate': 3.066666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4506, 'grad_norm': 6.650665283203125, 'learning_rate': 3.05e-05, 'epoch': 0.04}
# {'loss': 3.4719, 'grad_norm': 6.4491424560546875, 'learning_rate': 3.0333333333333337e-05, 'epoch': 0.04}
# {'loss': 3.359, 'grad_norm': 6.711708068847656, 'learning_rate': 3.016666666666667e-05, 'epoch': 0.04}
# {'loss': 3.4111, 'grad_norm': 6.353514194488525, 'learning_rate': 3e-05, 'epoch': 0.04}
# {'loss': 3.2437, 'grad_norm': 6.534818172454834, 'learning_rate': 2.9833333333333335e-05, 'epoch': 0.04}
# {'loss': 3.3418, 'grad_norm': 7.302549362182617, 'learning_rate': 2.9666666666666672e-05, 'epoch': 0.04}
# {'loss': 3.3826, 'grad_norm': 7.469418048858643, 'learning_rate': 2.95e-05, 'epoch': 0.04}
# {'loss': 3.3781, 'grad_norm': 10.237458229064941, 'learning_rate': 2.9333333333333336e-05, 'epoch': 0.04}
# {'loss': 3.4449, 'grad_norm': 6.674008846282959, 'learning_rate': 2.916666666666667e-05, 'epoch': 0.04}
# {'loss': 3.2775, 'grad_norm': 7.625395774841309, 'learning_rate': 2.9e-05, 'epoch': 0.04}
# {'loss': 3.4508, 'grad_norm': 7.221436977386475, 'learning_rate': 2.8833333333333334e-05, 'epoch': 0.04}
# {'loss': 3.3365, 'grad_norm': 7.281590461730957, 'learning_rate': 2.8666666666666668e-05, 'epoch': 0.04}
# {'loss': 3.3865, 'grad_norm': 6.847723484039307, 'learning_rate': 2.8499999999999998e-05, 'epoch': 0.05}
# {'loss': 3.4836, 'grad_norm': 7.404406547546387, 'learning_rate': 2.8333333333333335e-05, 'epoch': 0.05}
# {'loss': 3.4648, 'grad_norm': 6.979506969451904, 'learning_rate': 2.816666666666667e-05, 'epoch': 0.05}
# {'loss': 3.4529, 'grad_norm': 6.763244152069092, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.05}
# {'loss': 3.4002, 'grad_norm': 9.988533020019531, 'learning_rate': 2.7833333333333333e-05, 'epoch': 0.05}
# {'loss': 3.3033, 'grad_norm': 7.495349884033203, 'learning_rate': 2.7666666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3486, 'grad_norm': 7.475529193878174, 'learning_rate': 2.7500000000000004e-05, 'epoch': 0.05}
# {'loss': 3.3021, 'grad_norm': 7.824963092803955, 'learning_rate': 2.733333333333333e-05, 'epoch': 0.05}
# {'loss': 3.5125, 'grad_norm': 7.422633647918701, 'learning_rate': 2.716666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3814, 'grad_norm': 7.272339820861816, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.05}
# {'loss': 3.3551, 'grad_norm': 7.189523220062256, 'learning_rate': 2.6833333333333333e-05, 'epoch': 0.05}
# {'loss': 3.4182, 'grad_norm': 6.587329864501953, 'learning_rate': 2.6666666666666667e-05, 'epoch': 0.05}
# {'loss': 3.3482, 'grad_norm': 7.589056491851807, 'learning_rate': 2.6500000000000004e-05, 'epoch': 0.05}
# {'loss': 3.2687, 'grad_norm': 7.669871807098389, 'learning_rate': 2.633333333333333e-05, 'epoch': 0.05}
# {'loss': 3.3816, 'grad_norm': 7.70733642578125, 'learning_rate': 2.6166666666666668e-05, 'epoch': 0.05}
# {'loss': 3.3547, 'grad_norm': 7.177463531494141, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.05}
# {'loss': 3.2631, 'grad_norm': 6.846029758453369, 'learning_rate': 2.5833333333333336e-05, 'epoch': 0.05}
# {'loss': 3.393, 'grad_norm': 7.284451961517334, 'learning_rate': 2.5666666666666666e-05, 'epoch': 0.05}
# {'loss': 3.4369, 'grad_norm': 9.547602653503418, 'learning_rate': 2.5500000000000003e-05, 'epoch': 0.05}
# {'loss': 3.2961, 'grad_norm': 6.725594520568848, 'learning_rate': 2.5333333333333337e-05, 'epoch': 0.05}
# {'loss': 3.4395, 'grad_norm': 7.365024089813232, 'learning_rate': 2.5166666666666667e-05, 'epoch': 0.05}
# {'loss': 3.4521, 'grad_norm': 6.962459564208984, 'learning_rate': 2.5e-05, 'epoch': 0.05}
#  50%|███████████████████▌                   | 1500/3000 [19:12<14:15,  1.75it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:04<00:04,  2.06s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:08<00:02,  2.86s/it]
#
# {'eval_rouge-1': 32.523182, 'eval_rouge-2': 6.9225900000000005, 'eval_rouge-l': 25.483997999999996, 'eval_bleu-4': 0.034601977710479945, 'eval_runtime': 37.257, 'eval_samples_per_second': 1.342, 'eval_steps_per_second': 0.107, 'epoch': 0.05}
#  50%|███████████████████▌                   | 1500/3000 [19:49<14:15,  1.75it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:12<00:00,  3.24s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-1500
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3441, 'grad_norm': 6.994020462036133, 'learning_rate': 2.4833333333333335e-05, 'epoch': 0.05}
# {'loss': 3.3904, 'grad_norm': 7.954482555389404, 'learning_rate': 2.466666666666667e-05, 'epoch': 0.05}
# {'loss': 3.441, 'grad_norm': 8.222164154052734, 'learning_rate': 2.45e-05, 'epoch': 0.05}
# {'loss': 3.4041, 'grad_norm': 6.89520788192749, 'learning_rate': 2.4333333333333336e-05, 'epoch': 0.05}
# {'loss': 3.4936, 'grad_norm': 7.320033550262451, 'learning_rate': 2.4166666666666667e-05, 'epoch': 0.05}
# {'loss': 3.4076, 'grad_norm': 8.396870613098145, 'learning_rate': 2.4e-05, 'epoch': 0.05}
# {'loss': 3.4662, 'grad_norm': 8.067853927612305, 'learning_rate': 2.3833333333333334e-05, 'epoch': 0.05}
# {'loss': 3.435, 'grad_norm': 7.657225131988525, 'learning_rate': 2.3666666666666668e-05, 'epoch': 0.06}
# {'loss': 3.5105, 'grad_norm': 9.311060905456543, 'learning_rate': 2.35e-05, 'epoch': 0.06}
# {'loss': 3.392, 'grad_norm': 7.206541538238525, 'learning_rate': 2.3333333333333336e-05, 'epoch': 0.06}
# {'loss': 3.3623, 'grad_norm': 8.018177032470703, 'learning_rate': 2.3166666666666666e-05, 'epoch': 0.06}
# {'loss': 3.3719, 'grad_norm': 8.58680248260498, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.06}
# {'loss': 3.4721, 'grad_norm': 7.343184947967529, 'learning_rate': 2.2833333333333334e-05, 'epoch': 0.06}
# {'loss': 3.3197, 'grad_norm': 8.09437370300293, 'learning_rate': 2.2666666666666668e-05, 'epoch': 0.06}
# {'loss': 3.3732, 'grad_norm': 7.553764343261719, 'learning_rate': 2.25e-05, 'epoch': 0.06}
# {'loss': 3.3078, 'grad_norm': 7.114622592926025, 'learning_rate': 2.2333333333333335e-05, 'epoch': 0.06}
# {'loss': 3.4779, 'grad_norm': 8.619729042053223, 'learning_rate': 2.216666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3703, 'grad_norm': 7.1663994789123535, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.06}
# {'loss': 3.3766, 'grad_norm': 7.377490520477295, 'learning_rate': 2.1833333333333333e-05, 'epoch': 0.06}
# {'loss': 3.5186, 'grad_norm': 7.099363327026367, 'learning_rate': 2.1666666666666667e-05, 'epoch': 0.06}
# {'loss': 3.4596, 'grad_norm': 7.377104759216309, 'learning_rate': 2.15e-05, 'epoch': 0.06}
# {'loss': 3.5008, 'grad_norm': 7.3785858154296875, 'learning_rate': 2.1333333333333335e-05, 'epoch': 0.06}
# {'loss': 3.4004, 'grad_norm': 7.422767162322998, 'learning_rate': 2.116666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3984, 'grad_norm': 7.483641624450684, 'learning_rate': 2.1e-05, 'epoch': 0.06}
# {'loss': 3.4674, 'grad_norm': 7.529109954833984, 'learning_rate': 2.0833333333333336e-05, 'epoch': 0.06}
# {'loss': 3.4422, 'grad_norm': 7.863467216491699, 'learning_rate': 2.0666666666666666e-05, 'epoch': 0.06}
# {'loss': 3.3588, 'grad_norm': 8.156035423278809, 'learning_rate': 2.05e-05, 'epoch': 0.06}
# {'loss': 3.35, 'grad_norm': 8.243563652038574, 'learning_rate': 2.0333333333333334e-05, 'epoch': 0.06}
# {'loss': 3.392, 'grad_norm': 8.207571983337402, 'learning_rate': 2.0166666666666668e-05, 'epoch': 0.06}
# {'loss': 3.3375, 'grad_norm': 7.776810169219971, 'learning_rate': 2e-05, 'epoch': 0.06}
# {'loss': 3.3764, 'grad_norm': 9.046539306640625, 'learning_rate': 1.9833333333333335e-05, 'epoch': 0.06}
# {'loss': 3.3428, 'grad_norm': 7.926993370056152, 'learning_rate': 1.9666666666666666e-05, 'epoch': 0.06}
# {'loss': 3.5812, 'grad_norm': 7.896197319030762, 'learning_rate': 1.9500000000000003e-05, 'epoch': 0.06}
# {'loss': 3.3457, 'grad_norm': 8.530513763427734, 'learning_rate': 1.9333333333333333e-05, 'epoch': 0.06}
# {'loss': 3.4943, 'grad_norm': 8.97037124633789, 'learning_rate': 1.9166666666666667e-05, 'epoch': 0.06}
# {'loss': 3.3777, 'grad_norm': 7.408552646636963, 'learning_rate': 1.9e-05, 'epoch': 0.06}
# {'loss': 3.3145, 'grad_norm': 8.081805229187012, 'learning_rate': 1.8833333333333335e-05, 'epoch': 0.07}
# {'loss': 3.3031, 'grad_norm': 7.4542365074157715, 'learning_rate': 1.866666666666667e-05, 'epoch': 0.07}
# {'loss': 3.4059, 'grad_norm': 7.485490798950195, 'learning_rate': 1.85e-05, 'epoch': 0.07}
# {'loss': 3.376, 'grad_norm': 7.831222057342529, 'learning_rate': 1.8333333333333333e-05, 'epoch': 0.07}
# {'loss': 3.3955, 'grad_norm': 8.139955520629883, 'learning_rate': 1.8166666666666667e-05, 'epoch': 0.07}
# {'loss': 3.4852, 'grad_norm': 7.4816508293151855, 'learning_rate': 1.8e-05, 'epoch': 0.07}
# {'loss': 3.2803, 'grad_norm': 7.842004776000977, 'learning_rate': 1.7833333333333334e-05, 'epoch': 0.07}
# {'loss': 3.4963, 'grad_norm': 7.833934783935547, 'learning_rate': 1.7666666666666668e-05, 'epoch': 0.07}
# {'loss': 3.3639, 'grad_norm': 6.992100715637207, 'learning_rate': 1.75e-05, 'epoch': 0.07}
# {'loss': 3.2848, 'grad_norm': 8.858099937438965, 'learning_rate': 1.7333333333333336e-05, 'epoch': 0.07}
# {'loss': 3.3699, 'grad_norm': 7.671851634979248, 'learning_rate': 1.7166666666666666e-05, 'epoch': 0.07}
# {'loss': 3.2393, 'grad_norm': 7.710095405578613, 'learning_rate': 1.7000000000000003e-05, 'epoch': 0.07}
# {'loss': 3.4207, 'grad_norm': 7.115283966064453, 'learning_rate': 1.6833333333333334e-05, 'epoch': 0.07}
# {'loss': 3.4658, 'grad_norm': 7.986241817474365, 'learning_rate': 1.6666666666666667e-05, 'epoch': 0.07}
#  67%|██████████████████████████             | 2000/3000 [25:31<09:59,  1.67it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:05<00:05,  2.57s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:31<00:12, 12.46s/it]
#
# {'eval_rouge-1': 30.790954000000003, 'eval_rouge-2': 6.5821, 'eval_rouge-l': 23.416826000000004, 'eval_bleu-4': 0.0324729029949517, 'eval_runtime': 81.5152, 'eval_samples_per_second': 0.613, 'eval_steps_per_second': 0.049, 'epoch': 0.07}
#  67%|██████████████████████████             | 2000/3000 [26:52<09:59,  1.67it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:54<00:00, 16.23s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-2000
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3896, 'grad_norm': 8.766317367553711, 'learning_rate': 1.65e-05, 'epoch': 0.07}
# {'loss': 3.4945, 'grad_norm': 7.434551239013672, 'learning_rate': 1.6333333333333335e-05, 'epoch': 0.07}
# {'loss': 3.5545, 'grad_norm': 8.926178932189941, 'learning_rate': 1.6166666666666665e-05, 'epoch': 0.07}
# {'loss': 3.4891, 'grad_norm': 8.440035820007324, 'learning_rate': 1.6000000000000003e-05, 'epoch': 0.07}
# {'loss': 3.3684, 'grad_norm': 8.317359924316406, 'learning_rate': 1.5833333333333333e-05, 'epoch': 0.07}
# {'loss': 3.3248, 'grad_norm': 7.654841899871826, 'learning_rate': 1.5666666666666667e-05, 'epoch': 0.07}
# {'loss': 3.4426, 'grad_norm': 8.223163604736328, 'learning_rate': 1.55e-05, 'epoch': 0.07}
# {'loss': 3.4201, 'grad_norm': 8.455501556396484, 'learning_rate': 1.5333333333333334e-05, 'epoch': 0.07}
# {'loss': 3.4406, 'grad_norm': 7.524384021759033, 'learning_rate': 1.5166666666666668e-05, 'epoch': 0.07}
# {'loss': 3.3553, 'grad_norm': 7.6620965003967285, 'learning_rate': 1.5e-05, 'epoch': 0.07}
# {'loss': 3.2986, 'grad_norm': 7.685385704040527, 'learning_rate': 1.4833333333333336e-05, 'epoch': 0.07}
# {'loss': 3.5861, 'grad_norm': 7.975086688995361, 'learning_rate': 1.4666666666666668e-05, 'epoch': 0.07}
# {'loss': 3.2467, 'grad_norm': 7.616588592529297, 'learning_rate': 1.45e-05, 'epoch': 0.07}
# {'loss': 3.358, 'grad_norm': 8.443869590759277, 'learning_rate': 1.4333333333333334e-05, 'epoch': 0.07}
# {'loss': 3.399, 'grad_norm': 7.402510166168213, 'learning_rate': 1.4166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.517, 'grad_norm': 8.039616584777832, 'learning_rate': 1.4000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.3943, 'grad_norm': 6.959627628326416, 'learning_rate': 1.3833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.415, 'grad_norm': 7.961684226989746, 'learning_rate': 1.3666666666666666e-05, 'epoch': 0.08}
# {'loss': 3.3549, 'grad_norm': 7.65752649307251, 'learning_rate': 1.3500000000000001e-05, 'epoch': 0.08}
# {'loss': 3.4355, 'grad_norm': 7.611126899719238, 'learning_rate': 1.3333333333333333e-05, 'epoch': 0.08}
# {'loss': 3.451, 'grad_norm': 6.937392711639404, 'learning_rate': 1.3166666666666665e-05, 'epoch': 0.08}
# {'loss': 3.4184, 'grad_norm': 7.804297924041748, 'learning_rate': 1.3000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.4193, 'grad_norm': 8.193524360656738, 'learning_rate': 1.2833333333333333e-05, 'epoch': 0.08}
# {'loss': 3.3748, 'grad_norm': 8.177189826965332, 'learning_rate': 1.2666666666666668e-05, 'epoch': 0.08}
# {'loss': 3.243, 'grad_norm': 8.474857330322266, 'learning_rate': 1.25e-05, 'epoch': 0.08}
# {'loss': 3.3662, 'grad_norm': 7.910257816314697, 'learning_rate': 1.2333333333333334e-05, 'epoch': 0.08}
# {'loss': 3.4271, 'grad_norm': 8.735092163085938, 'learning_rate': 1.2166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.4656, 'grad_norm': 7.734390735626221, 'learning_rate': 1.2e-05, 'epoch': 0.08}
# {'loss': 3.2912, 'grad_norm': 8.578696250915527, 'learning_rate': 1.1833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.3598, 'grad_norm': 8.347054481506348, 'learning_rate': 1.1666666666666668e-05, 'epoch': 0.08}
# {'loss': 3.3217, 'grad_norm': 8.53359603881836, 'learning_rate': 1.1500000000000002e-05, 'epoch': 0.08}
# {'loss': 3.3258, 'grad_norm': 8.488070487976074, 'learning_rate': 1.1333333333333334e-05, 'epoch': 0.08}
# {'loss': 3.3689, 'grad_norm': 8.851838111877441, 'learning_rate': 1.1166666666666668e-05, 'epoch': 0.08}
# {'loss': 3.3631, 'grad_norm': 7.826488018035889, 'learning_rate': 1.1000000000000001e-05, 'epoch': 0.08}
# {'loss': 3.2686, 'grad_norm': 8.577394485473633, 'learning_rate': 1.0833333333333334e-05, 'epoch': 0.08}
# {'loss': 3.376, 'grad_norm': 8.211058616638184, 'learning_rate': 1.0666666666666667e-05, 'epoch': 0.08}
# {'loss': 3.3543, 'grad_norm': 7.975450038909912, 'learning_rate': 1.05e-05, 'epoch': 0.08}
# {'loss': 3.4928, 'grad_norm': 8.621670722961426, 'learning_rate': 1.0333333333333333e-05, 'epoch': 0.08}
# {'loss': 3.2332, 'grad_norm': 8.404757499694824, 'learning_rate': 1.0166666666666667e-05, 'epoch': 0.08}
# {'loss': 3.4555, 'grad_norm': 7.8500142097473145, 'learning_rate': 1e-05, 'epoch': 0.08}
# {'loss': 3.4555, 'grad_norm': 8.18244457244873, 'learning_rate': 9.833333333333333e-06, 'epoch': 0.08}
# {'loss': 3.2787, 'grad_norm': 8.195451736450195, 'learning_rate': 9.666666666666667e-06, 'epoch': 0.08}
# {'loss': 3.3684, 'grad_norm': 7.472768783569336, 'learning_rate': 9.5e-06, 'epoch': 0.08}
# {'loss': 3.3791, 'grad_norm': 8.007569313049316, 'learning_rate': 9.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.2748, 'grad_norm': 7.750097274780273, 'learning_rate': 9.166666666666666e-06, 'epoch': 0.09}
# {'loss': 3.3121, 'grad_norm': 7.907119274139404, 'learning_rate': 9e-06, 'epoch': 0.09}
# {'loss': 3.2588, 'grad_norm': 8.830833435058594, 'learning_rate': 8.833333333333334e-06, 'epoch': 0.09}
# {'loss': 3.4387, 'grad_norm': 7.537350177764893, 'learning_rate': 8.666666666666668e-06, 'epoch': 0.09}
# {'loss': 3.4705, 'grad_norm': 7.764716625213623, 'learning_rate': 8.500000000000002e-06, 'epoch': 0.09}
# {'loss': 3.3965, 'grad_norm': 9.571429252624512, 'learning_rate': 8.333333333333334e-06, 'epoch': 0.09}
#  83%|████████████████████████████████▌      | 2500/3000 [32:35<05:39,  1.47it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:06<00:06,  3.08s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:10<00:03,  3.53s/it]
#
# {'eval_rouge-1': 32.21192, 'eval_rouge-2': 7.25814, 'eval_rouge-l': 25.411388000000002, 'eval_bleu-4': 0.03408067944509339, 'eval_runtime': 60.0389, 'eval_samples_per_second': 0.833, 'eval_steps_per_second': 0.067, 'epoch': 0.09}
#  83%|████████████████████████████████▌      | 2500/3000 [33:35<05:39,  1.47it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:33<00:00, 10.64s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-2500
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
# {'loss': 3.3002, 'grad_norm': 8.602901458740234, 'learning_rate': 8.166666666666668e-06, 'epoch': 0.09}
# {'loss': 3.3414, 'grad_norm': 10.62633228302002, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.09}
# {'loss': 3.2482, 'grad_norm': 7.904267311096191, 'learning_rate': 7.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.3963, 'grad_norm': 8.400379180908203, 'learning_rate': 7.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.3891, 'grad_norm': 7.736935138702393, 'learning_rate': 7.5e-06, 'epoch': 0.09}
# {'loss': 3.4021, 'grad_norm': 8.517841339111328, 'learning_rate': 7.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.4738, 'grad_norm': 8.137794494628906, 'learning_rate': 7.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.4787, 'grad_norm': 8.570657730102539, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.09}
# {'loss': 3.3744, 'grad_norm': 8.480618476867676, 'learning_rate': 6.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.4775, 'grad_norm': 8.75042724609375, 'learning_rate': 6.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.3533, 'grad_norm': 8.137492179870605, 'learning_rate': 6.5000000000000004e-06, 'epoch': 0.09}
# {'loss': 3.4238, 'grad_norm': 7.840600967407227, 'learning_rate': 6.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.5238, 'grad_norm': 7.553389072418213, 'learning_rate': 6.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.4414, 'grad_norm': 8.687660217285156, 'learning_rate': 6e-06, 'epoch': 0.09}
# {'loss': 3.4045, 'grad_norm': 8.10488224029541, 'learning_rate': 5.833333333333334e-06, 'epoch': 0.09}
# {'loss': 3.3506, 'grad_norm': 7.97343635559082, 'learning_rate': 5.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.4154, 'grad_norm': 8.742835998535156, 'learning_rate': 5.500000000000001e-06, 'epoch': 0.09}
# {'loss': 3.2715, 'grad_norm': 7.624241352081299, 'learning_rate': 5.333333333333334e-06, 'epoch': 0.09}
# {'loss': 3.4695, 'grad_norm': 8.751364707946777, 'learning_rate': 5.166666666666667e-06, 'epoch': 0.09}
# {'loss': 3.4516, 'grad_norm': 8.849234580993652, 'learning_rate': 5e-06, 'epoch': 0.09}
# {'loss': 3.426, 'grad_norm': 8.36599349975586, 'learning_rate': 4.833333333333333e-06, 'epoch': 0.09}
# {'loss': 3.2504, 'grad_norm': 7.850647926330566, 'learning_rate': 4.666666666666667e-06, 'epoch': 0.09}
# {'loss': 3.3779, 'grad_norm': 8.026514053344727, 'learning_rate': 4.5e-06, 'epoch': 0.1}
# {'loss': 3.3891, 'grad_norm': 8.203614234924316, 'learning_rate': 4.333333333333334e-06, 'epoch': 0.1}
# {'loss': 3.4586, 'grad_norm': 8.962102890014648, 'learning_rate': 4.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.4, 'grad_norm': 8.18759536743164, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.1}
# {'loss': 3.3488, 'grad_norm': 8.335139274597168, 'learning_rate': 3.833333333333334e-06, 'epoch': 0.1}
# {'loss': 3.2609, 'grad_norm': 8.72365665435791, 'learning_rate': 3.666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.2812, 'grad_norm': 8.21090030670166, 'learning_rate': 3.5000000000000004e-06, 'epoch': 0.1}
# {'loss': 3.2418, 'grad_norm': 7.893138885498047, 'learning_rate': 3.3333333333333333e-06, 'epoch': 0.1}
# {'loss': 3.4496, 'grad_norm': 7.805877685546875, 'learning_rate': 3.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.3748, 'grad_norm': 8.168063163757324, 'learning_rate': 3e-06, 'epoch': 0.1}
# {'loss': 3.3906, 'grad_norm': 8.029083251953125, 'learning_rate': 2.8333333333333335e-06, 'epoch': 0.1}
# {'loss': 3.4432, 'grad_norm': 9.058748245239258, 'learning_rate': 2.666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.4045, 'grad_norm': 8.801895141601562, 'learning_rate': 2.5e-06, 'epoch': 0.1}
# {'loss': 3.3367, 'grad_norm': 8.398231506347656, 'learning_rate': 2.3333333333333336e-06, 'epoch': 0.1}
# {'loss': 3.3764, 'grad_norm': 8.784430503845215, 'learning_rate': 2.166666666666667e-06, 'epoch': 0.1}
# {'loss': 3.5098, 'grad_norm': 9.355025291442871, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.1}
# {'loss': 3.3043, 'grad_norm': 8.17900276184082, 'learning_rate': 1.8333333333333335e-06, 'epoch': 0.1}
# {'loss': 3.3275, 'grad_norm': 8.979350090026855, 'learning_rate': 1.6666666666666667e-06, 'epoch': 0.1}
# {'loss': 3.308, 'grad_norm': 7.88848352432251, 'learning_rate': 1.5e-06, 'epoch': 0.1}
# {'loss': 3.2492, 'grad_norm': 7.333057880401611, 'learning_rate': 1.3333333333333334e-06, 'epoch': 0.1}
# {'loss': 3.3611, 'grad_norm': 9.027170181274414, 'learning_rate': 1.1666666666666668e-06, 'epoch': 0.1}
# {'loss': 3.2543, 'grad_norm': 8.439841270446777, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.1}
# {'loss': 3.3787, 'grad_norm': 8.133649826049805, 'learning_rate': 8.333333333333333e-07, 'epoch': 0.1}
# {'loss': 3.2068, 'grad_norm': 9.015071868896484, 'learning_rate': 6.666666666666667e-07, 'epoch': 0.1}
# {'loss': 3.4488, 'grad_norm': 8.82603931427002, 'learning_rate': 5.000000000000001e-07, 'epoch': 0.1}
# {'loss': 3.4299, 'grad_norm': 8.879961013793945, 'learning_rate': 3.3333333333333335e-07, 'epoch': 0.1}
# {'loss': 3.4758, 'grad_norm': 8.23680591583252, 'learning_rate': 1.6666666666666668e-07, 'epoch': 0.1}
# {'loss': 3.365, 'grad_norm': 7.8778767585754395, 'learning_rate': 0.0, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [39:16<00:00,  1.43it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:24<00:24, 12.21s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:27<00:08,  8.55s/it]
#
# {'eval_rouge-1': 32.334179999999996, 'eval_rouge-2': 6.8705739999999995, 'eval_rouge-l': 24.197743999999997, 'eval_bleu-4': 0.03315465275680029, 'eval_runtime': 78.0406, 'eval_samples_per_second': 0.641, 'eval_steps_per_second': 0.051, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [40:34<00:00,  1.43it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:50<00:00, 13.90s/it]
#                                                                                 Saving model checkpoint to ./output/checkpoint-3000
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/103caa40027ebfd8450289ca2f278eac4ff26405/config.json
# Model config ChatGLMConfig {
#   "_name_or_path": "THUDM/chatglm3-6b",
#   "add_bias_linear": false,
#   "add_qkv_bias": true,
#   "apply_query_key_layer_scaling": true,
#   "apply_residual_connection_post_layernorm": false,
#   "architectures": [
#     "ChatGLMModel"
#   ],
#   "attention_dropout": 0.0,
#   "attention_softmax_in_fp32": true,
#   "auto_map": {
#     "AutoConfig": "THUDM/chatglm3-6b--configuration_chatglm.ChatGLMConfig",
#     "AutoModel": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForCausalLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSeq2SeqLM": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForConditionalGeneration",
#     "AutoModelForSequenceClassification": "THUDM/chatglm3-6b--modeling_chatglm.ChatGLMForSequenceClassification"
#   },
#   "bias_dropout_fusion": true,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "ffn_hidden_size": 13696,
#   "fp32_residual_connection": false,
#   "hidden_dropout": 0.0,
#   "hidden_size": 4096,
#   "kv_channels": 128,
#   "layernorm_epsilon": 1e-05,
#   "model_type": "chatglm",
#   "multi_query_attention": true,
#   "multi_query_group_num": 2,
#   "num_attention_heads": 32,
#   "num_layers": 28,
#   "original_rope": true,
#   "pad_token_id": 0,
#   "padded_vocab_size": 65024,
#   "post_layer_norm": true,
#   "pre_seq_len": null,
#   "prefix_projection": false,
#   "quantization_bit": 0,
#   "rmsnorm": true,
#   "seq_length": 8192,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float16",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "vocab_size": 65024
# }
#
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 2435.1035, 'train_samples_per_second': 4.928, 'train_steps_per_second': 1.232, 'train_loss': 3.4456901041666668, 'epoch': 0.1}
# 100%|███████████████████████████████████████| 3000/3000 [40:35<00:00,  1.23it/s]
# ***** Running Prediction *****
#   Num examples = 1070
#   Batch size = 16
# 100%|███████████████████████████████████████████| 67/67 [17:59<00:00, 16.12s/it]

# %% [markdown]
# ## 3. 使用微调的数据集进行推理
# 在完成微调任务之后，我们可以查看到 `output` 文件夹下多了很多个`checkpoint-*`的文件夹，这些文件夹代表了训练的轮数。
# 我们选择最后一轮的微调权重，并使用inference进行导入。

# %%
# !CUDA_VISIBLE_DEVICES=0 NCCL_P2P_DISABLE="1" NCCL_IB_DISABLE="1" python inference_hf.py output/checkpoint-3000/ --prompt "类型#裙*版型#显瘦*材质#网纱*风格#性感*裙型#百褶*裙下摆#压褶*裙长#连衣裙*裙衣门襟#拉链*裙衣门襟#套头*裙款式#拼接*裙款式#拉链*裙款式#木耳边*裙款式#抽褶*裙款式#不规则"
# Out:
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:02<00:00,  2.77it/s]
# Setting eos_token is not supported, use the default one.
# Setting pad_token is not supported, use the default one.
# Setting unk_token is not supported, use the default one.
# 这款连衣裙采用网纱拼接设计，视觉上更加性感，不规则的木耳边设计，让整体更加有层次感，不规则的压褶设计，让裙摆更加飘逸，拉链套头设计，方便穿脱，不规则的裙摆设计，让裙身更加有层次感，显瘦效果更佳。这款连衣裙采用网纱拼接设计，视觉上更加性感，不规则的木耳边设计，让整体更加有层次感，不规则的压褶设计，让裙摆更加飘逸，拉链套头设计，方便穿脱，不规则的裙摆设计，让裙身更加有层次感，显瘦效果更佳。

# %% [markdown]
# ## 4. 总结
# 到此位置，我们就完成了使用单张 GPU Lora 来微调 ChatGLM3-6B 模型，使其能生产出更好的广告。
# 在本章节中，你将会学会：
# + 如何使用模型进行 Lora 微调
# + 微调数据集的准备和对齐
# + 使用微调的模型进行推理
